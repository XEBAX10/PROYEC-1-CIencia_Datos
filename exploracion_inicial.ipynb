# %%
import pandas as pd
from pathlib import Path

DATOS = Path("Reporte_Capturas_Policía_Nacional_20260915.csv")
df = pd.read_csv(DATOS)
print(f"Filas: {len(df):,}  Columnas: {len(df.columns)}")
df.head()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_25500\1881387374.py:5: DtypeWarning: Columns (0: CODIGO DANE) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(DATOS)
# Filas: 3,746,786  Columnas: 8
#   Departamento             Municipio CODIGO DANE FECHA HECHO     GENERO  \
# 0        HUILA            Neiva (CT)    41001000  01/01/2010  MASCULINO
# 1       NARIÑO  San Andres de Tumaco    52835000  01/01/2010  MASCULINO
# 2    SANTANDER       Barrancabermeja    68081000  01/01/2010  MASCULINO
# 3    SANTANDER       Barrancabermeja    68081000  01/01/2010  MASCULINO
# 4       BOGOTA      Bogotá D.C. (CT)    11001000  01/01/2010  MASCULINO
#
#                         DESCRIPCION CONDUCTA CAPTURA GRUPO ETARIO  CANTIDAD
# 0                  ARTÍCULO 111. LESIONES PERSONALES      ADULTOS         1
# 1  ARTÍCULO 376. TRÁFICO, FABRICACIÓN O PORTE DE ...      ADULTOS         1
# ...
