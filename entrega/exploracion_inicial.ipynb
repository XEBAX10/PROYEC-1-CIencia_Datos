# %%
import pandas as pd
from pathlib import Path

DATOS = Path("../Presuntos_Homicidios._Colombia,_2015_a_2024._Cifras_definitivas_20260916.csv")
df = pd.read_csv(DATOS)
print(f"Filas: {len(df):,}  Columnas: {len(df.columns)}")
df.head()
# Out:
# Filas: 125,284  Columnas: 33
#    ID  Año del hecho Grupo de edad quinquenal    Grupo Mayor Menor de Edad  \
# 0   1           2015                (20 a 24)  b) Mayor de Edad (>18 Años)
# 1   2           2015                (25 a 29)  b) Mayor de Edad (>18 Años)
# 2   3           2015                (20 a 24)  b) Mayor de Edad (>18 Años)
# 3   4           2015                (30 a 34)  b) Mayor de Edad (>18 Años)
# 4   5           2015                (25 a 29)  b) Mayor de Edad (>18 Años)
#
#   Grupo de Edad judicial         Ciclo Vital Sexo de la victima Estado Civil  \
# 0              (20 a 24)  (18 a 28) Juventud             Hombre   Soltero(a)
# 1              (25 a 28)  (18 a 28) Juventud             Hombre   Soltero(a)
# 2              (20 a 24)  (18 a 28) Juventud             Hombre   Soltero(a)
# 3              (29 a 34)   (29 a 59) Adultez              Mujer   Soltero(a)
# 4              (25 a 28)  (18 a 28) Juventud             Hombre   Soltero(a)
#
# ...
